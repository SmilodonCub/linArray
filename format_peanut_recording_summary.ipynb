# %% [markdown]
# # Format Peanut Recording Summary

# %%
import pandas as pd

# %%
path = '/home/bonzilla/Documents/ScienceLife/linArray/linArray/Peanut_Recording_Summary.xlsx'
summary = pd.read_excel(path, engine='openpyxl')

# %%
summary.head()
# Out:
#   track       Date Chamber track_AP track_ML   Cortex   Quiet    SC  Track   \
# 0    T1 2017-01-10      SC      NaN       NaN     14.0   17.0  23.6     NaN
# 1  FEF1 2017-02-21     FEF        0        3L      NaN    NaN   NaN     NaN
# 2    T2 2017-03-08      SC       4P        3L     12.0   18.0  21.9     NaN
# 3    T3 2017-03-10      SC       4P        2L      7.0   15.8  21.9     NaN
# 4  T4_1 2017-03-21      SC       4P        4L      8.5   21.7  23.2    23.6
#
#   RF_theta  RF amp.       .plx   delay_num_trials  \
# 0  Up & Rt      5.0         NaN               NaN
# 1      NaN      NaN         NaN               NaN
# 2      NaN      NaN         NaN               NaN
# 3      NaN      NaN         NaN               NaN
# 4       15      6.0  Peanut.plx              10.0
#
#    catSearchPHYSIOL_num_trials  delayANTI_num_trials  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# ...

# %%
summary.to_csv('summary_peanut.csv', index=False)

# %%
summary = pd.read_csv( 'summary_peanut.csv' )
summary.head()
# Out:
#   track        Date Chamber track_AP track_ML   Cortex   Quiet    SC  Track   \
# 0    T1  2017-01-10      SC      NaN       NaN     14.0   17.0  23.6     NaN
# 1  FEF1  2017-02-21     FEF        0        3L      NaN    NaN   NaN     NaN
# 2    T2  2017-03-08      SC       4P        3L     12.0   18.0  21.9     NaN
# 3    T3  2017-03-10      SC       4P        2L      7.0   15.8  21.9     NaN
# 4  T4_1  2017-03-21      SC       4P        4L      8.5   21.7  23.2    23.6
#
#   RF_theta  RF amp.       .plx   delay_num_trials  \
# 0  Up & Rt      5.0         NaN               NaN
# 1      NaN      NaN         NaN               NaN
# 2      NaN      NaN         NaN               NaN
# 3      NaN      NaN         NaN               NaN
# 4       15      6.0  Peanut.plx              10.0
#
#    catSearchPHYSIOL_num_trials  delayANTI_num_trials  \
# 0                          NaN                   NaN
# 1                          NaN                   NaN
# ...
