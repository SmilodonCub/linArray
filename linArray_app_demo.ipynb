# %% [markdown]
# # Linear Array Channel Browzer

# %% [markdown]
# ## An app for visualizing combined behavioral and neural data collected using Plexon Linear Arrays

# %% [markdown]
# ### for the McPeek lab

# %% [markdown]
# From the menus below, select a Track, Channel, and Task of interest

# %%
import alignment_functions as af
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_pkls = {'T35_083018_t1':"T35_083018_t1_delayedSaccade.pkl",
             'T35_083018_t2':"T35_083018_t2_delayedSaccade.pkl",
             'T35_083018_t3':"T35_083018_t3_delayedSaccade.pkl"}
chosen_file = 'T35_083018_t2'
chosen_path = data_pkls[chosen_file]
print( chosen_path )
df = pd.read_pickle( chosen_path )
# Out:
# T35_083018_t2_delayedSaccade.pkl

# %%
DS_saccadeOnset_ts = 'saccade_onset'
DS_stimOn_ts = 'bhv_code40'
time_axis_limits_ms = [ -50, 150 ]
recordings = df['neuralDat'].unique()
recordings
# Out:
# array(['T35_083018_t2_spikingDAT.mat'], dtype=object)

# %%
filter_col = [col for col in df if col.startswith('SPK')]

# %%
combinedalign = af.eyespike_dualAligned( df, filter_col[3], DS_stimOn_ts, DS_saccadeOnset_ts, time_axis_limits_ms, 0  )
plt.show( combinedalign )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 50 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                14 non-null     int64
#  1   start                14 non-null     float64
#  2   end                  14 non-null     float64
#  3   SPK09i               14 non-null     object
#  4   SPK10i               14 non-null     object
#  5   SPK11i               14 non-null     object
#  6   SPK12i               14 non-null     object
#  7   SPK13a               14 non-null     object
#  8   SPK13i               14 non-null     object
#  9   SPK14i               14 non-null     object
#  10  SPK15a               14 non-null     object
#  11  SPK15i               14 non-null     object
#  12  SPK16a               14 non-null     object
#  13  SPK16i               14 non-null     object
#  14  Strobed00030         14 non-null     object
# ...
